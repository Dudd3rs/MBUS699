# %% [markdown]
# <a href="https://colab.research.google.com/github/Dudd3rs/MBUS699/blob/main/MBUS699.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Welcome to Dunn's MBUS 699 Machine Learning Notebook**
# This first program block is an exploration of numpy features.
# Python notebooks have immediately become priceless with the ability to seamlessly incorporate text, math, and code.  Super cool!
#
# $A=pi(r)^2$
#
# $dA/dr=2*pi*r$

# %%
from numpy.random.mtrand import randint
import numpy as np
a = 4+36
b=np.ndarray(shape=(2,2),dtype=int)
a*b*0
b[0][0]=1;b[0][1]=2;b[1][0]=1;b[1][1]=2;
a=sum(b)
c=randint(30,100,size=(2,2))
print("a=",a,"\n")
print(b,"\n",c)
b=c/b
print(b)
# Out:
# a= [2 4]
#
# [[1 2]
#  [1 2]]
#  [[87 32]
#  [70 58]]
# [[87. 16.]
#  [70. 29.]]

# %% [markdown]
# This next section is some scatter plots and an attempt at linear regression on random integers, but it is mad.  Something wrong with arrays?

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
x=randint(100,size=(2,1000),)
plt.scatter(x[0],x[1])
y=x[1]-x[0]
a=np.array([x[0],y])
plt.scatter(a[0],a[1])
#I can't get the regression model to work correctly, think the arrays made it mad.  Suggestions?
reg=linear_model.LinearRegression()
reg.fit(a,a)
# Out:
# LinearRegression()

# %% [markdown]
# This third section is the exploration of Google's Teachable Machine.  We are using 18 publically available images of bikes, with 3 classifications of bike.  All images were received from https://www.pinkbike.com/, and test
# images can be pulled from the same location.  This model successfully identified 2 of 4 test images.
#
# Link: https://teachablemachine.withgoogle.com/models/4MzJuhpxJ/
#
#
# ![Test1pass.JPG](data:image/jpeg;base64,...)

# %%
#learning some pandas db for classification study
import pandas as pd
import numpy as np
#THIS DOESNT WORK data=pd.read_csv('https://github.com/Dudd3rs/MBUS699/blob/b86c154f8914ca578265da8544c8c3f3b7b20f37/CR1000XSeries_Table1_20220307.csv',index_col=0)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-19-b1692b926ba6> in <module>
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 data=pd.read_csv('https://github.com/Dudd3rs/MBUS699/blob/b86c154f8914ca578265da8544c8c3f3b7b20f37/CR1000XSeries_Table1_20220307.csv',index_col=0)
#       5 df=pd.dataframe(data,index_col=0)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     222         try:
#     223             if self.low_memory:
# --> 224                 chunks = self._reader.read_low_memory(nrows)
#     225                 # destructive to chunks
#     226                 data = _concatenate_chunks(chunks)
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 28, saw 436
